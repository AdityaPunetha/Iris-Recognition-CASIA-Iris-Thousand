# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (1.0.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 74.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.21.6)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# Successfully installed scikit-learn-1.2.0

# %%
import cv2
import numpy as np
import glob
import pickle
# from sklearn.externals import joblib
import joblib
from keras.applications.vgg16 import preprocess_input
from sklearn import preprocessing
from keras.utils import to_categorical
from keras.preprocessing import image
import numpy as np
import glob
import keras
from keras.models       import Model
from keras.applications.densenet import DenseNet121
from keras.applications.vgg16 import VGG16
from keras.applications.densenet import DenseNet121
from keras.models import Model
import glob

# %%
imgs=[]
final_output_84_84=[]
lables=[]
for filefilepath in glob.iglob('/content/drive/MyDrive/colab/final_MMU/*'):
    
    
    if filefilepath[-1] == 'g':
        
        img	= cv2.imread(filefilepath)
        imgs_colored=cv2.imread(filefilepath)
        #img=cv2.resize(img,(200,150))
        #imgs_colored.append(img)

        print(filefilepath)
        #print(filefilepath[19:-6])
        #print(filefilepath[-5])
        split = filefilepath.split(".")
        #print(split)
        print(split[0][39:])
        print(split[1])

        label=split[0][39:]
        example_number = split[1]
        imgs.append([imgs_colored,int(label)])
        #final_output_84_84.append(imgs_colored)
        #lables.append(int(label))
    
import random

random.shuffle(imgs)

for i,j in imgs:
        final_output_84_84.append(i)
        lables.append(j)
    
print(len(final_output_84_84))
print(len(lables))
# Out:
# /content/drive/MyDrive/colab/final_MMU/30.9.jpg
# 30
# 9
# /content/drive/MyDrive/colab/final_MMU/30.5.jpg
# 30
# 5
# /content/drive/MyDrive/colab/final_MMU/43.1.jpg
# 43
# 1
# /content/drive/MyDrive/colab/final_MMU/40.6.jpg
# 40
# 6
# /content/drive/MyDrive/colab/final_MMU/38.5.jpg
# 38
# 5
# /content/drive/MyDrive/colab/final_MMU/16.5.jpg
# 16
# 5
# /content/drive/MyDrive/colab/final_MMU/0.4.jpg
# 0
# 4
# /content/drive/MyDrive/colab/final_MMU/27.3.jpg
# 27
# 3
# /content/drive/MyDrive/colab/final_MMU/11.3.jpg
# 11
# 3
# /content/drive/MyDrive/colab/final_MMU/40.9.jpg
# 40
# 9
# /content/drive/MyDrive/colab/final_MMU/25.6.jpg
# 25
# 6
# /content/drive/MyDrive/colab/final_MMU/21.4.jpg
# 21
# 4
# /content/drive/MyDrive/colab/final_MMU/1.4.jpg
# 1
# 4
# /content/drive/MyDrive/colab/final_MMU/23.0.jpg
# 23
# 0
# /content/drive/MyDrive/colab/final_MMU/26.7.jpg
# 26
# 7
# /content/drive/MyDrive/colab/final_MMU/6.3.jpg
# 6
# 3
# /content/drive/MyDrive/colab/final_MMU/30.0.jpg
# 30
# 0
# /content/drive/MyDrive/colab/final_MMU/35.9.jpg
# 35
# 9
# /content/drive/MyDrive/colab/final_MMU/36.1.jpg
# 36
# 1
# /content/drive/MyDrive/colab/final_MMU/8.1.jpg
# 8
# 1
# /content/drive/MyDrive/colab/final_MMU/25.5.jpg
# 25
# 5
# /content/drive/MyDrive/colab/final_MMU/36.9.jpg
# 36
# 9
# /content/drive/MyDrive/colab/final_MMU/2.6.jpg
# 2
# 6
# /content/drive/MyDrive/colab/final_MMU/27.5.jpg
# 27
# 5
# /content/drive/MyDrive/colab/final_MMU/5.7.jpg
# 5
# 7
# /content/drive/MyDrive/colab/final_MMU/1.1.jpg
# 1
# 1
# /content/drive/MyDrive/colab/final_MMU/18.5.jpg
# 18
# 5
# /content/drive/MyDrive/colab/final_MMU/1.3.jpg
# 1
# 3
# /content/drive/MyDrive/colab/final_MMU/36.5.jpg
# 36
# 5
# /content/drive/MyDrive/colab/final_MMU/39.8.jpg
# 39
# 8
# /content/drive/MyDrive/colab/final_MMU/13.6.jpg
# 13
# 6
# /content/drive/MyDrive/colab/final_MMU/18.0.jpg
# 18
# 0
# /content/drive/MyDrive/colab/final_MMU/35.1.jpg
# 35
# 1
# /content/drive/MyDrive/colab/final_MMU/35.3.jpg
# 35
# 3
# /content/drive/MyDrive/colab/final_MMU/10.1.jpg
# 10
# 1
# /content/drive/MyDrive/colab/final_MMU/31.6.jpg
# 31
# 6
# /content/drive/MyDrive/colab/final_MMU/11.6.jpg
# 11
# 6
# /content/drive/MyDrive/colab/final_MMU/29.9.jpg
# 29
# 9
# /content/drive/MyDrive/colab/final_MMU/3.1.jpg
# 3
# 1
# /content/drive/MyDrive/colab/final_MMU/0.1.jpg
# 0
# 1
# /content/drive/MyDrive/colab/final_MMU/10.8.jpg
# 10
# 8
# /content/drive/MyDrive/colab/final_MMU/26.5.jpg
# 26
# 5
# /content/drive/MyDrive/colab/final_MMU/13.7.jpg
# 13
# 7
# /content/drive/MyDrive/colab/final_MMU/40.1.jpg
# 40
# 1
# /content/drive/MyDrive/colab/final_MMU/10.9.jpg
# 10
# 9
# /content/drive/MyDrive/colab/final_MMU/23.8.jpg
# 23
# 8
# /content/drive/MyDrive/colab/final_MMU/43.9.jpg
# 43
# 9
# /content/drive/MyDrive/colab/final_MMU/28.2.jpg
# 28
# 2
# /content/drive/MyDrive/colab/final_MMU/2.0.jpg
# 2
# 0
# /content/drive/MyDrive/colab/final_MMU/38.9.jpg
# 38
# 9
# /content/drive/MyDrive/colab/final_MMU/11.7.jpg
# 11
# 7
# /content/drive/MyDrive/colab/final_MMU/7.6.jpg
# 7
# 6
# /content/drive/MyDrive/colab/final_MMU/30.3.jpg
# 30
# 3
# /content/drive/MyDrive/colab/final_MMU/3.4.jpg
# 3
# 4
# /content/drive/MyDrive/colab/final_MMU/13.4.jpg
# 13
# 4
# /content/drive/MyDrive/colab/final_MMU/20.0.jpg
# 20
# 0
# /content/drive/MyDrive/colab/final_MMU/12.1.jpg
# 12
# 1
# /content/drive/MyDrive/colab/final_MMU/3.2.jpg
# 3
# 2
# /content/drive/MyDrive/colab/final_MMU/44.1.jpg
# 44
# 1
# /content/drive/MyDrive/colab/final_MMU/2.5.jpg
# 2
# 5
# /content/drive/MyDrive/colab/final_MMU/39.5.jpg
# 39
# 5
# /content/drive/MyDrive/colab/final_MMU/15.3.jpg
# 15
# 3
# /content/drive/MyDrive/colab/final_MMU/5.9.jpg
# 5
# 9
# /content/drive/MyDrive/colab/final_MMU/34.5.jpg
# 34
# 5
# /content/drive/MyDrive/colab/final_MMU/39.1.jpg
# 39
# 1
# /content/drive/MyDrive/colab/final_MMU/11.2.jpg
# 11
# 2
# /content/drive/MyDrive/colab/final_MMU/40.8.jpg
# 40
# 8
# /content/drive/MyDrive/colab/final_MMU/13.5.jpg
# 13
# 5
# /content/drive/MyDrive/colab/final_MMU/7.9.jpg
# 7
# 9
# /content/drive/MyDrive/colab/final_MMU/20.5.jpg
# 20
# 5
# /content/drive/MyDrive/colab/final_MMU/28.9.jpg
# 28
# 9
# /content/drive/MyDrive/colab/final_MMU/14.3.jpg
# 14
# 3
# /content/drive/MyDrive/colab/final_MMU/33.5.jpg
# 33
# 5
# /content/drive/MyDrive/colab/final_MMU/41.0.jpg
# 41
# 0
# /content/drive/MyDrive/colab/final_MMU/15.6.jpg
# 15
# 6
# /content/drive/MyDrive/colab/final_MMU/9.8.jpg
# 9
# 8
# /content/drive/MyDrive/colab/final_MMU/29.3.jpg
# 29
# 3
# /content/drive/MyDrive/colab/final_MMU/21.7.jpg
# 21
# 7
# /content/drive/MyDrive/colab/final_MMU/3.5.jpg
# 3
# 5
# /content/drive/MyDrive/colab/final_MMU/14.5.jpg
# 14
# 5
# /content/drive/MyDrive/colab/final_MMU/5.0.jpg
# 5
# 0
# /content/drive/MyDrive/colab/final_MMU/24.2.jpg
# 24
# 2
# /content/drive/MyDrive/colab/final_MMU/24.4.jpg
# 24
# 4
# /content/drive/MyDrive/colab/final_MMU/42.4.jpg
# 42
# 4
# /content/drive/MyDrive/colab/final_MMU/31.9.jpg
# 31
# 9
# /content/drive/MyDrive/colab/final_MMU/7.0.jpg
# 7
# 0
# /content/drive/MyDrive/colab/final_MMU/5.3.jpg
# 5
# 3
# /content/drive/MyDrive/colab/final_MMU/33.0.jpg
# 33
# 0
# /content/drive/MyDrive/colab/final_MMU/4.1.jpg
# 4
# 1
# /content/drive/MyDrive/colab/final_MMU/18.1.jpg
# 18
# 1
# /content/drive/MyDrive/colab/final_MMU/2.2.jpg
# 2
# 2
# /content/drive/MyDrive/colab/final_MMU/37.2.jpg
# 37
# 2
# /content/drive/MyDrive/colab/final_MMU/22.4.jpg
# 22
# 4
# /content/drive/MyDrive/colab/final_MMU/25.2.jpg
# 25
# 2
# /content/drive/MyDrive/colab/final_MMU/25.0.jpg
# 25
# 0
# /content/drive/MyDrive/colab/final_MMU/38.0.jpg
# 38
# 0
# /content/drive/MyDrive/colab/final_MMU/23.5.jpg
# 23
# 5
# /content/drive/MyDrive/colab/final_MMU/10.6.jpg
# 10
# 6
# /content/drive/MyDrive/colab/final_MMU/11.9.jpg
# 11
# 9
# /content/drive/MyDrive/colab/final_MMU/9.3.jpg
# 9
# 3
# /content/drive/MyDrive/colab/final_MMU/40.4.jpg
# 40
# 4
# /content/drive/MyDrive/colab/final_MMU/12.0.jpg
# 12
# 0
# /content/drive/MyDrive/colab/final_MMU/16.1.jpg
# 16
# 1
# /content/drive/MyDrive/colab/final_MMU/6.2.jpg
# 6
# 2
# /content/drive/MyDrive/colab/final_MMU/24.1.jpg
# 24
# 1
# /content/drive/MyDrive/colab/final_MMU/19.3.jpg
# 19
# 3
# /content/drive/MyDrive/colab/final_MMU/15.8.jpg
# 15
# 8
# /content/drive/MyDrive/colab/final_MMU/40.7.jpg
# 40
# 7
# /content/drive/MyDrive/colab/final_MMU/20.7.jpg
# 20
# 7
# /content/drive/MyDrive/colab/final_MMU/10.3.jpg
# 10
# 3
# /content/drive/MyDrive/colab/final_MMU/42.3.jpg
# 42
# 3
# /content/drive/MyDrive/colab/final_MMU/35.7.jpg
# 35
# 7
# /content/drive/MyDrive/colab/final_MMU/34.9.jpg
# 34
# 9
# /content/drive/MyDrive/colab/final_MMU/9.1.jpg
# 9
# 1
# /content/drive/MyDrive/colab/final_MMU/21.8.jpg
# 21
# 8
# /content/drive/MyDrive/colab/final_MMU/8.8.jpg
# 8
# 8
# /content/drive/MyDrive/colab/final_MMU/10.5.jpg
# 10
# 5
# /content/drive/MyDrive/colab/final_MMU/31.8.jpg
# 31
# 8
# /content/drive/MyDrive/colab/final_MMU/42.1.jpg
# 42
# 1
# /content/drive/MyDrive/colab/final_MMU/36.0.jpg
# 36
# 0
# /content/drive/MyDrive/colab/final_MMU/8.7.jpg
# 8
# 7
# /content/drive/MyDrive/colab/final_MMU/27.6.jpg
# 27
# 6
# /content/drive/MyDrive/colab/final_MMU/34.8.jpg
# 34
# 8
# /content/drive/MyDrive/colab/final_MMU/40.2.jpg
# 40
# 2
# /content/drive/MyDrive/colab/final_MMU/34.6.jpg
# 34
# 6
# /content/drive/MyDrive/colab/final_MMU/39.6.jpg
# 39
# 6
# /content/drive/MyDrive/colab/final_MMU/7.2.jpg
# 7
# 2
# /content/drive/MyDrive/colab/final_MMU/40.5.jpg
# 40
# 5
# /content/drive/MyDrive/colab/final_MMU/23.2.jpg
# 23
# 2
# /content/drive/MyDrive/colab/final_MMU/5.2.jpg
# 5
# 2
# /content/drive/MyDrive/colab/final_MMU/44.6.jpg
# 44
# 6
# /content/drive/MyDrive/colab/final_MMU/19.6.jpg
# 19
# 6
# /content/drive/MyDrive/colab/final_MMU/44.2.jpg
# 44
# 2
# /content/drive/MyDrive/colab/final_MMU/15.7.jpg
# 15
# 7
# /content/drive/MyDrive/colab/final_MMU/32.1.jpg
# 32
# 1
# /content/drive/MyDrive/colab/final_MMU/28.5.jpg
# 28
# 5
# /content/drive/MyDrive/colab/final_MMU/1.7.jpg
# 1
# 7
# /content/drive/MyDrive/colab/final_MMU/31.4.jpg
# 31
# 4
# /content/drive/MyDrive/colab/final_MMU/12.2.jpg
# 12
# 2
# /content/drive/MyDrive/colab/final_MMU/22.7.jpg
# 22
# 7
# /content/drive/MyDrive/colab/final_MMU/44.7.jpg
# 44
# 7
# /content/drive/MyDrive/colab/final_MMU/4.8.jpg
# 4
# 8
# /content/drive/MyDrive/colab/final_MMU/1.9.jpg
# 1
# 9
# /content/drive/MyDrive/colab/final_MMU/44.0.jpg
# 44
# 0
# /content/drive/MyDrive/colab/final_MMU/41.3.jpg
# 41
# 3
# /content/drive/MyDrive/colab/final_MMU/28.8.jpg
# 28
# 8
# /content/drive/MyDrive/colab/final_MMU/12.4.jpg
# 12
# 4
# /content/drive/MyDrive/colab/final_MMU/7.5.jpg
# 7
# 5
# /content/drive/MyDrive/colab/final_MMU/32.6.jpg
# 32
# 6
# /content/drive/MyDrive/colab/final_MMU/1.2.jpg
# 1
# 2
# /content/drive/MyDrive/colab/final_MMU/37.5.jpg
# 37
# 5
# /content/drive/MyDrive/colab/final_MMU/15.1.jpg
# 15
# 1
# /content/drive/MyDrive/colab/final_MMU/22.3.jpg
# 22
# 3
# /content/drive/MyDrive/colab/final_MMU/19.2.jpg
# 19
# 2
# /content/drive/MyDrive/colab/final_MMU/28.0.jpg
# 28
# 0
# /content/drive/MyDrive/colab/final_MMU/36.8.jpg
# 36
# 8
# /content/drive/MyDrive/colab/final_MMU/40.3.jpg
# 40
# 3
# /content/drive/MyDrive/colab/final_MMU/27.9.jpg
# 27
# 9
# /content/drive/MyDrive/colab/final_MMU/31.7.jpg
# 31
# 7
# /content/drive/MyDrive/colab/final_MMU/30.1.jpg
# 30
# 1
# /content/drive/MyDrive/colab/final_MMU/18.3.jpg
# 18
# 3
# /content/drive/MyDrive/colab/final_MMU/6.4.jpg
# 6
# 4
# /content/drive/MyDrive/colab/final_MMU/41.6.jpg
# 41
# 6
# /content/drive/MyDrive/colab/final_MMU/9.7.jpg
# 9
# 7
# /content/drive/MyDrive/colab/final_MMU/42.8.jpg
# 42
# 8
# /content/drive/MyDrive/colab/final_MMU/25.8.jpg
# 25
# 8
# /content/drive/MyDrive/colab/final_MMU/6.1.jpg
# 6
# 1
# /content/drive/MyDrive/colab/final_MMU/27.8.jpg
# 27
# 8
# /content/drive/MyDrive/colab/final_MMU/14.6.jpg
# 14
# 6
# /content/drive/MyDrive/colab/final_MMU/14.7.jpg
# 14
# 7
# /content/drive/MyDrive/colab/final_MMU/20.8.jpg
# 20
# 8
# /content/drive/MyDrive/colab/final_MMU/10.2.jpg
# 10
# 2
# /content/drive/MyDrive/colab/final_MMU/10.7.jpg
# 10
# 7
# /content/drive/MyDrive/colab/final_MMU/37.3.jpg
# 37
# 3
# /content/drive/MyDrive/colab/final_MMU/16.9.jpg
# 16
# 9
# /content/drive/MyDrive/colab/final_MMU/6.5.jpg
# 6
# 5
# /content/drive/MyDrive/colab/final_MMU/39.4.jpg
# 39
# 4
# /content/drive/MyDrive/colab/final_MMU/5.5.jpg
# 5
# 5
# /content/drive/MyDrive/colab/final_MMU/44.5.jpg
# 44
# 5
# /content/drive/MyDrive/colab/final_MMU/14.8.jpg
# 14
# 8
# /content/drive/MyDrive/colab/final_MMU/29.1.jpg
# 29
# 1
# /content/drive/MyDrive/colab/final_MMU/36.6.jpg
# 36
# 6
# /content/drive/MyDrive/colab/final_MMU/33.1.jpg
# 33
# 1
# /content/drive/MyDrive/colab/final_MMU/23.7.jpg
# 23
# 7
# /content/drive/MyDrive/colab/final_MMU/25.9.jpg
# 25
# 9
# /content/drive/MyDrive/colab/final_MMU/30.8.jpg
# 30
# 8
# /content/drive/MyDrive/colab/final_MMU/21.1.jpg
# 21
# 1
# /content/drive/MyDrive/colab/final_MMU/8.3.jpg
# 8
# 3
# /content/drive/MyDrive/colab/final_MMU/20.3.jpg
# 20
# 3
# /content/drive/MyDrive/colab/final_MMU/41.1.jpg
# 41
# 1
# /content/drive/MyDrive/colab/final_MMU/20.6.jpg
# 20
# 6
# /content/drive/MyDrive/colab/final_MMU/25.1.jpg
# 25
# 1
# /content/drive/MyDrive/colab/final_MMU/43.3.jpg
# 43
# 3
# /content/drive/MyDrive/colab/final_MMU/41.8.jpg
# 41
# 8
# /content/drive/MyDrive/colab/final_MMU/32.7.jpg
# 32
# 7
# /content/drive/MyDrive/colab/final_MMU/8.9.jpg
# 8
# 9
# /content/drive/MyDrive/colab/final_MMU/14.2.jpg
# 14
# 2
# /content/drive/MyDrive/colab/final_MMU/17.5.jpg
# 17
# 5
# /content/drive/MyDrive/colab/final_MMU/34.1.jpg
# 34
# 1
# /content/drive/MyDrive/colab/final_MMU/9.5.jpg
# 9
# 5
# /content/drive/MyDrive/colab/final_MMU/29.6.jpg
# 29
# 6
# /content/drive/MyDrive/colab/final_MMU/4.7.jpg
# 4
# 7
# /content/drive/MyDrive/colab/final_MMU/5.1.jpg
# 5
# 1
# /content/drive/MyDrive/colab/final_MMU/0.7.jpg
# 0
# 7
# /content/drive/MyDrive/colab/final_MMU/0.9.jpg
# 0
# 9
# /content/drive/MyDrive/colab/final_MMU/25.4.jpg
# 25
# 4
# /content/drive/MyDrive/colab/final_MMU/43.8.jpg
# 43
# 8
# /content/drive/MyDrive/colab/final_MMU/23.1.jpg
# 23
# 1
# /content/drive/MyDrive/colab/final_MMU/16.3.jpg
# 16
# 3
# /content/drive/MyDrive/colab/final_MMU/18.8.jpg
# 18
# 8
# /content/drive/MyDrive/colab/final_MMU/0.6.jpg
# 0
# 6
# /content/drive/MyDrive/colab/final_MMU/26.1.jpg
# 26
# 1
# /content/drive/MyDrive/colab/final_MMU/18.7.jpg
# 18
# 7
# /content/drive/MyDrive/colab/final_MMU/32.4.jpg
# 32
# 4
# /content/drive/MyDrive/colab/final_MMU/2.4.jpg
# 2
# 4
# /content/drive/MyDrive/colab/final_MMU/14.0.jpg
# 14
# 0
# /content/drive/MyDrive/colab/final_MMU/28.4.jpg
# 28
# 4
# /content/drive/MyDrive/colab/final_MMU/15.5.jpg
# 15
# 5
# /content/drive/MyDrive/colab/final_MMU/38.7.jpg
# 38
# 7
# /content/drive/MyDrive/colab/final_MMU/41.4.jpg
# 41
# 4
# /content/drive/MyDrive/colab/final_MMU/11.4.jpg
# 11
# 4
# /content/drive/MyDrive/colab/final_MMU/22.1.jpg
# 22
# 1
# /content/drive/MyDrive/colab/final_MMU/31.0.jpg
# 31
# 0
# /content/drive/MyDrive/colab/final_MMU/26.9.jpg
# 26
# 9
# /content/drive/MyDrive/colab/final_MMU/33.7.jpg
# 33
# 7
# /content/drive/MyDrive/colab/final_MMU/28.7.jpg
# 28
# 7
# /content/drive/MyDrive/colab/final_MMU/13.2.jpg
# 13
# 2
# /content/drive/MyDrive/colab/final_MMU/6.8.jpg
# 6
# 8
# /content/drive/MyDrive/colab/final_MMU/0.3.jpg
# 0
# 3
# /content/drive/MyDrive/colab/final_MMU/15.4.jpg
# 15
# 4
# /content/drive/MyDrive/colab/final_MMU/32.2.jpg
# 32
# 2
# /content/drive/MyDrive/colab/final_MMU/43.2.jpg
# 43
# 2
# /content/drive/MyDrive/colab/final_MMU/11.5.jpg
# 11
# 5
# /content/drive/MyDrive/colab/final_MMU/18.9.jpg
# 18
# 9
# /content/drive/MyDrive/colab/final_MMU/43.7.jpg
# 43
# 7
# /content/drive/MyDrive/colab/final_MMU/4.3.jpg
# 4
# 3
# /content/drive/MyDrive/colab/final_MMU/12.3.jpg
# 12
# 3
# /content/drive/MyDrive/colab/final_MMU/30.2.jpg
# 30
# 2
# /content/drive/MyDrive/colab/final_MMU/9.2.jpg
# 9
# 2
# /content/drive/MyDrive/colab/final_MMU/28.6.jpg
# 28
# 6
# /content/drive/MyDrive/colab/final_MMU/27.1.jpg
# 27
# 1
# /content/drive/MyDrive/colab/final_MMU/1.0.jpg
# 1
# 0
# /content/drive/MyDrive/colab/final_MMU/17.6.jpg
# 17
# 6
# /content/drive/MyDrive/colab/final_MMU/3.7.jpg
# 3
# 7
# /content/drive/MyDrive/colab/final_MMU/21.9.jpg
# 21
# 9
# /content/drive/MyDrive/colab/final_MMU/19.8.jpg
# 19
# 8
# /content/drive/MyDrive/colab/final_MMU/0.2.jpg
# 0
# 2
# /content/drive/MyDrive/colab/final_MMU/3.9.jpg
# 3
# 9
# /content/drive/MyDrive/colab/final_MMU/24.6.jpg
# 24
# 6
# /content/drive/MyDrive/colab/final_MMU/9.4.jpg
# 9
# 4
# /content/drive/MyDrive/colab/final_MMU/14.4.jpg
# 14
# 4
# /content/drive/MyDrive/colab/final_MMU/33.9.jpg
# 33
# 9
# /content/drive/MyDrive/colab/final_MMU/9.9.jpg
# 9
# 9
# /content/drive/MyDrive/colab/final_MMU/16.0.jpg
# 16
# 0
# /content/drive/MyDrive/colab/final_MMU/9.0.jpg
# 9
# 0
# /content/drive/MyDrive/colab/final_MMU/27.4.jpg
# 27
# 4
# /content/drive/MyDrive/colab/final_MMU/17.8.jpg
# 17
# 8
# /content/drive/MyDrive/colab/final_MMU/25.3.jpg
# 25
# 3
# /content/drive/MyDrive/colab/final_MMU/4.6.jpg
# 4
# 6
# /content/drive/MyDrive/colab/final_MMU/6.6.jpg
# 6
# 6
# /content/drive/MyDrive/colab/final_MMU/31.1.jpg
# 31
# 1
# /content/drive/MyDrive/colab/final_MMU/26.2.jpg
# 26
# 2
# /content/drive/MyDrive/colab/final_MMU/44.9.jpg
# 44
# 9
# /content/drive/MyDrive/colab/final_MMU/13.0.jpg
# 13
# 0
# /content/drive/MyDrive/colab/final_MMU/19.1.jpg
# 19
# 1
# /content/drive/MyDrive/colab/final_MMU/16.4.jpg
# 16
# 4
# /content/drive/MyDrive/colab/final_MMU/20.2.jpg
# 20
# 2
# /content/drive/MyDrive/colab/final_MMU/24.0.jpg
# 24
# 0
# /content/drive/MyDrive/colab/final_MMU/39.7.jpg
# 39
# 7
# /content/drive/MyDrive/colab/final_MMU/0.5.jpg
# 0
# 5
# /content/drive/MyDrive/colab/final_MMU/39.2.jpg
# 39
# 2
# /content/drive/MyDrive/colab/final_MMU/21.0.jpg
# 21
# 0
# /content/drive/MyDrive/colab/final_MMU/15.2.jpg
# 15
# 2
# /content/drive/MyDrive/colab/final_MMU/24.9.jpg
# 24
# 9
# /content/drive/MyDrive/colab/final_MMU/7.8.jpg
# 7
# 8
# /content/drive/MyDrive/colab/final_MMU/34.7.jpg
# 34
# 7
# /content/drive/MyDrive/colab/final_MMU/27.7.jpg
# 27
# 7
# /content/drive/MyDrive/colab/final_MMU/19.7.jpg
# 19
# 7
# /content/drive/MyDrive/colab/final_MMU/21.3.jpg
# 21
# 3
# /content/drive/MyDrive/colab/final_MMU/8.0.jpg
# 8
# 0
# /content/drive/MyDrive/colab/final_MMU/12.7.jpg
# 12
# 7
# /content/drive/MyDrive/colab/final_MMU/24.8.jpg
# 24
# 8
# /content/drive/MyDrive/colab/final_MMU/17.3.jpg
# 17
# 3
# /content/drive/MyDrive/colab/final_MMU/24.3.jpg
# 24
# 3
# /content/drive/MyDrive/colab/final_MMU/3.8.jpg
# 3
# 8
# /content/drive/MyDrive/colab/final_MMU/44.4.jpg
# 44
# 4
# /content/drive/MyDrive/colab/final_MMU/16.2.jpg
# 16
# 2
# /content/drive/MyDrive/colab/final_MMU/25.7.jpg
# 25
# 7
# /content/drive/MyDrive/colab/final_MMU/37.9.jpg
# 37
# 9
# /content/drive/MyDrive/colab/final_MMU/22.6.jpg
# 22
# 6
# /content/drive/MyDrive/colab/final_MMU/41.9.jpg
# 41
# 9
# /content/drive/MyDrive/colab/final_MMU/0.8.jpg
# 0
# 8
# /content/drive/MyDrive/colab/final_MMU/17.9.jpg
# 17
# 9
# /content/drive/MyDrive/colab/final_MMU/39.0.jpg
# 39
# 0
# /content/drive/MyDrive/colab/final_MMU/22.8.jpg
# 22
# 8
# /content/drive/MyDrive/colab/final_MMU/42.7.jpg
# 42
# 7
# /content/drive/MyDrive/colab/final_MMU/3.3.jpg
# 3
# 3
# /content/drive/MyDrive/colab/final_MMU/6.7.jpg
# 6
# 7
# /content/drive/MyDrive/colab/final_MMU/32.0.jpg
# 32
# 0
# /content/drive/MyDrive/colab/final_MMU/22.5.jpg
# 22
# 5
# /content/drive/MyDrive/colab/final_MMU/33.6.jpg
# 33
# 6
# /content/drive/MyDrive/colab/final_MMU/21.2.jpg
# 21
# 2
# /content/drive/MyDrive/colab/final_MMU/34.3.jpg
# 34
# 3
# /content/drive/MyDrive/colab/final_MMU/27.0.jpg
# 27
# 0
# /content/drive/MyDrive/colab/final_MMU/22.0.jpg
# 22
# 0
# /content/drive/MyDrive/colab/final_MMU/26.8.jpg
# 26
# 8
# /content/drive/MyDrive/colab/final_MMU/35.2.jpg
# 35
# 2
# /content/drive/MyDrive/colab/final_MMU/33.3.jpg
# 33
# 3
# /content/drive/MyDrive/colab/final_MMU/44.8.jpg
# 44
# 8
# /content/drive/MyDrive/colab/final_MMU/4.4.jpg
# 4
# 4
# /content/drive/MyDrive/colab/final_MMU/43.6.jpg
# 43
# 6
# /content/drive/MyDrive/colab/final_MMU/29.2.jpg
# 29
# 2
# /content/drive/MyDrive/colab/final_MMU/35.6.jpg
# 35
# 6
# /content/drive/MyDrive/colab/final_MMU/6.0.jpg
# 6
# 0
# /content/drive/MyDrive/colab/final_MMU/34.0.jpg
# 34
# 0
# /content/drive/MyDrive/colab/final_MMU/32.5.jpg
# 32
# 5
# /content/drive/MyDrive/colab/final_MMU/29.4.jpg
# 29
# 4
# /content/drive/MyDrive/colab/final_MMU/8.2.jpg
# 8
# 2
# /content/drive/MyDrive/colab/final_MMU/32.8.jpg
# 32
# 8
# /content/drive/MyDrive/colab/final_MMU/38.6.jpg
# 38
# 6
# /content/drive/MyDrive/colab/final_MMU/42.5.jpg
# 42
# 5
# /content/drive/MyDrive/colab/final_MMU/20.4.jpg
# 20
# 4
# /content/drive/MyDrive/colab/final_MMU/38.1.jpg
# 38
# 1
# /content/drive/MyDrive/colab/final_MMU/38.3.jpg
# 38
# 3
# /content/drive/MyDrive/colab/final_MMU/2.9.jpg
# 2
# 9
# /content/drive/MyDrive/colab/final_MMU/40.0.jpg
# 40
# 0
# /content/drive/MyDrive/colab/final_MMU/1.8.jpg
# 1
# 8
# /content/drive/MyDrive/colab/final_MMU/5.4.jpg
# 5
# 4
# /content/drive/MyDrive/colab/final_MMU/37.4.jpg
# 37
# 4
# /content/drive/MyDrive/colab/final_MMU/35.8.jpg
# 35
# 8
# /content/drive/MyDrive/colab/final_MMU/17.7.jpg
# 17
# 7
# /content/drive/MyDrive/colab/final_MMU/41.7.jpg
# 41
# 7
# /content/drive/MyDrive/colab/final_MMU/0.0.jpg
# 0
# 0
# /content/drive/MyDrive/colab/final_MMU/2.7.jpg
# 2
# 7
# /content/drive/MyDrive/colab/final_MMU/30.6.jpg
# 30
# 6
# /content/drive/MyDrive/colab/final_MMU/5.6.jpg
# 5
# 6
# /content/drive/MyDrive/colab/final_MMU/29.7.jpg
# 29
# 7
# /content/drive/MyDrive/colab/final_MMU/3.6.jpg
# 3
# 6
# /content/drive/MyDrive/colab/final_MMU/37.6.jpg
# 37
# 6
# /content/drive/MyDrive/colab/final_MMU/16.7.jpg
# 16
# 7
# /content/drive/MyDrive/colab/final_MMU/44.3.jpg
# 44
# 3
# /content/drive/MyDrive/colab/final_MMU/29.0.jpg
# 29
# 0
# /content/drive/MyDrive/colab/final_MMU/23.6.jpg
# 23
# 6
# /content/drive/MyDrive/colab/final_MMU/15.0.jpg
# 15
# 0
# /content/drive/MyDrive/colab/final_MMU/38.4.jpg
# 38
# 4
# /content/drive/MyDrive/colab/final_MMU/36.7.jpg
# 36
# 7
# /content/drive/MyDrive/colab/final_MMU/9.6.jpg
# 9
# 6
# /content/drive/MyDrive/colab/final_MMU/11.8.jpg
# 11
# 8
# /content/drive/MyDrive/colab/final_MMU/39.9.jpg
# 39
# 9
# /content/drive/MyDrive/colab/final_MMU/27.2.jpg
# 27
# 2
# /content/drive/MyDrive/colab/final_MMU/31.3.jpg
# 31
# 3
# /content/drive/MyDrive/colab/final_MMU/19.4.jpg
# 19
# 4
# /content/drive/MyDrive/colab/final_MMU/17.2.jpg
# 17
# 2
# /content/drive/MyDrive/colab/final_MMU/13.8.jpg
# 13
# 8
# /content/drive/MyDrive/colab/final_MMU/6.9.jpg
# 6
# 9
# /content/drive/MyDrive/colab/final_MMU/1.6.jpg
# 1
# 6
# /content/drive/MyDrive/colab/final_MMU/4.9.jpg
# 4
# 9
# /content/drive/MyDrive/colab/final_MMU/5.8.jpg
# 5
# 8
# /content/drive/MyDrive/colab/final_MMU/32.9.jpg
# 32
# 9
# /content/drive/MyDrive/colab/final_MMU/31.2.jpg
# 31
# 2
# /content/drive/MyDrive/colab/final_MMU/33.2.jpg
# 33
# 2
# /content/drive/MyDrive/colab/final_MMU/41.5.jpg
# 41
# 5
# /content/drive/MyDrive/colab/final_MMU/14.1.jpg
# 14
# 1
# /content/drive/MyDrive/colab/final_MMU/33.4.jpg
# 33
# 4
# /content/drive/MyDrive/colab/final_MMU/10.0.jpg
# 10
# 0
# /content/drive/MyDrive/colab/final_MMU/17.1.jpg
# 17
# 1
# /content/drive/MyDrive/colab/final_MMU/4.2.jpg
# 4
# 2
# /content/drive/MyDrive/colab/final_MMU/21.5.jpg
# 21
# 5
# /content/drive/MyDrive/colab/final_MMU/43.0.jpg
# 43
# 0
# /content/drive/MyDrive/colab/final_MMU/35.4.jpg
# 35
# 4
# /content/drive/MyDrive/colab/final_MMU/24.7.jpg
# 24
# 7
# /content/drive/MyDrive/colab/final_MMU/41.2.jpg
# 41
# 2
# /content/drive/MyDrive/colab/final_MMU/4.0.jpg
# 4
# 0
# /content/drive/MyDrive/colab/final_MMU/35.0.jpg
# 35
# 0
# /content/drive/MyDrive/colab/final_MMU/8.4.jpg
# 8
# 4
# /content/drive/MyDrive/colab/final_MMU/36.3.jpg
# 36
# 3
# /content/drive/MyDrive/colab/final_MMU/1.5.jpg
# 1
# 5
# /content/drive/MyDrive/colab/final_MMU/12.9.jpg
# 12
# 9
# /content/drive/MyDrive/colab/final_MMU/37.7.jpg
# 37
# 7
# /content/drive/MyDrive/colab/final_MMU/24.5.jpg
# 24
# 5
# /content/drive/MyDrive/colab/final_MMU/20.9.jpg
# 20
# 9
# /content/drive/MyDrive/colab/final_MMU/14.9.jpg
# 14
# 9
# /content/drive/MyDrive/colab/final_MMU/7.1.jpg
# 7
# 1
# /content/drive/MyDrive/colab/final_MMU/16.8.jpg
# 16
# 8
# /content/drive/MyDrive/colab/final_MMU/18.2.jpg
# 18
# 2
# /content/drive/MyDrive/colab/final_MMU/17.0.jpg
# 17
# 0
# /content/drive/MyDrive/colab/final_MMU/42.2.jpg
# 42
# 2
# /content/drive/MyDrive/colab/final_MMU/18.4.jpg
# 18
# 4
# /content/drive/MyDrive/colab/final_MMU/37.1.jpg
# 37
# 1
# /content/drive/MyDrive/colab/final_MMU/3.0.jpg
# 3
# 0
# /content/drive/MyDrive/colab/final_MMU/10.4.jpg
# 10
# 4
# /content/drive/MyDrive/colab/final_MMU/29.8.jpg
# 29
# 8
# /content/drive/MyDrive/colab/final_MMU/2.3.jpg
# 2
# 3
# /content/drive/MyDrive/colab/final_MMU/8.5.jpg
# 8
# 5
# /content/drive/MyDrive/colab/final_MMU/23.4.jpg
# 23
# 4
# /content/drive/MyDrive/colab/final_MMU/23.3.jpg
# 23
# 3
# /content/drive/MyDrive/colab/final_MMU/7.4.jpg
# 7
# 4
# /content/drive/MyDrive/colab/final_MMU/15.9.jpg
# 15
# 9
# /content/drive/MyDrive/colab/final_MMU/13.1.jpg
# 13
# 1
# /content/drive/MyDrive/colab/final_MMU/2.8.jpg
# 2
# 8
# /content/drive/MyDrive/colab/final_MMU/8.6.jpg
# 8
# 6
# /content/drive/MyDrive/colab/final_MMU/31.5.jpg
# 31
# 5
# /content/drive/MyDrive/colab/final_MMU/32.3.jpg
# 32
# 3
# /content/drive/MyDrive/colab/final_MMU/12.6.jpg
# 12
# 6
# /content/drive/MyDrive/colab/final_MMU/42.9.jpg
# 42
# 9
# /content/drive/MyDrive/colab/final_MMU/26.6.jpg
# 26
# 6
# /content/drive/MyDrive/colab/final_MMU/42.0.jpg
# 42
# 0
# /content/drive/MyDrive/colab/final_MMU/30.7.jpg
# 30
# 7
# /content/drive/MyDrive/colab/final_MMU/28.3.jpg
# 28
# 3
# /content/drive/MyDrive/colab/final_MMU/34.4.jpg
# 34
# 4
# /content/drive/MyDrive/colab/final_MMU/4.5.jpg
# 4
# 5
# /content/drive/MyDrive/colab/final_MMU/30.4.jpg
# 30
# 4
# /content/drive/MyDrive/colab/final_MMU/16.6.jpg
# 16
# 6
# /content/drive/MyDrive/colab/final_MMU/2.1.jpg
# 2
# 1
# /content/drive/MyDrive/colab/final_MMU/39.3.jpg
# 39
# 3
# /content/drive/MyDrive/colab/final_MMU/28.1.jpg
# 28
# 1
# /content/drive/MyDrive/colab/final_MMU/43.4.jpg
# 43
# 4
# /content/drive/MyDrive/colab/final_MMU/22.9.jpg
# 22
# 9
# /content/drive/MyDrive/colab/final_MMU/7.7.jpg
# 7
# 7
# /content/drive/MyDrive/colab/final_MMU/11.1.jpg
# 11
# 1
# /content/drive/MyDrive/colab/final_MMU/29.5.jpg
# 29
# 5
# /content/drive/MyDrive/colab/final_MMU/42.6.jpg
# 42
# 6
# /content/drive/MyDrive/colab/final_MMU/7.3.jpg
# 7
# 3
# /content/drive/MyDrive/colab/final_MMU/21.6.jpg
# 21
# 6
# /content/drive/MyDrive/colab/final_MMU/36.4.jpg
# 36
# 4
# /content/drive/MyDrive/colab/final_MMU/34.2.jpg
# 34
# 2
# /content/drive/MyDrive/colab/final_MMU/19.9.jpg
# 19
# 9
# /content/drive/MyDrive/colab/final_MMU/37.8.jpg
# 37
# 8
# /content/drive/MyDrive/colab/final_MMU/17.4.jpg
# 17
# 4
# /content/drive/MyDrive/colab/final_MMU/33.8.jpg
# 33
# 8
# /content/drive/MyDrive/colab/final_MMU/12.5.jpg
# 12
# 5
# /content/drive/MyDrive/colab/final_MMU/18.6.jpg
# 18
# 6
# /content/drive/MyDrive/colab/final_MMU/20.1.jpg
# 20
# 1
# /content/drive/MyDrive/colab/final_MMU/19.5.jpg
# 19
# 5
# /content/drive/MyDrive/colab/final_MMU/13.9.jpg
# 13
# 9
# /content/drive/MyDrive/colab/final_MMU/22.2.jpg
# 22
# 2
# /content/drive/MyDrive/colab/final_MMU/11.0.jpg
# 11
# 0
# /content/drive/MyDrive/colab/final_MMU/38.2.jpg
# 38
# 2
# /content/drive/MyDrive/colab/final_MMU/12.8.jpg
# 12
# 8
# /content/drive/MyDrive/colab/final_MMU/37.0.jpg
# 37
# 0
# /content/drive/MyDrive/colab/final_MMU/43.5.jpg
# 43
# 5
# /content/drive/MyDrive/colab/final_MMU/36.2.jpg
# 36
# 2
# /content/drive/MyDrive/colab/final_MMU/26.4.jpg
# 26
# 4
# /content/drive/MyDrive/colab/final_MMU/26.3.jpg
# 26
# 3
# /content/drive/MyDrive/colab/final_MMU/26.0.jpg
# 26
# 0
# /content/drive/MyDrive/colab/final_MMU/35.5.jpg
# 35
# 5
# /content/drive/MyDrive/colab/final_MMU/19.0.jpg
# 19
# 0
# /content/drive/MyDrive/colab/final_MMU/23.9.jpg
# 23
# 9
# /content/drive/MyDrive/colab/final_MMU/38.8.jpg
# 38
# 8
# /content/drive/MyDrive/colab/final_MMU/13.3.jpg
# 13
# 3
# 450
# 450

# %%
#lables

# %%
img_size=(70,70)

# %%
y=keras.utils.to_categorical(lables, num_classes=1000, dtype='float32')

# %%
final_output_84_84 = np.array(final_output_84_84,dtype="float16")/255

# %%
final_output_84_84[0].size
# Out:
# 90000

# %%
from keras.models       import Model
from keras.applications.densenet import DenseNet201
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.applications.xception import Xception

#original_model = VGG16(include_top=False)
original_model = DenseNet201(include_top=False)
#original_model = InceptionV3(include_top=False)
#original_model = InceptionResNetV2(include_top=False)
#original_model = Xception(include_top=False)

bottleneck_input  = original_model.get_layer(index=0).input
bottleneck_output = original_model.get_layer(index=-59).output
bottleneck_model  = Model(inputs=bottleneck_input,  outputs=bottleneck_output)

bottleneck_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  zero_padding2d (ZeroPadding2D)  (None, None, None,   0          ['input_1[0][0]']
#                                 3)
#
#  conv1/conv (Conv2D)            (None, None, None,   9408        ['zero_padding2d[0][0]']
#                                 64)
#
#  conv1/bn (BatchNormalization)  (None, None, None,   256         ['conv1/conv[0][0]']
#                                 64)
#
#  conv1/relu (Activation)        (None, None, None,   0           ['conv1/bn[0][0]']
#                                 64)
#
#  zero_padding2d_1 (ZeroPadding2  (None, None, None,   0          ['conv1/relu[0][0]']
#  D)                             64)
#
#  pool1 (MaxPooling2D)           (None, None, None,   0           ['zero_padding2d_1[0][0]']
#                                 64)
#
#  conv2_block1_0_bn (BatchNormal  (None, None, None,   256        ['pool1[0][0]']
#  ization)                       64)
#
#  conv2_block1_0_relu (Activatio  (None, None, None,   0          ['conv2_block1_0_bn[0][0]']
#  n)                             64)
#
#  conv2_block1_1_conv (Conv2D)   (None, None, None,   8192        ['conv2_block1_0_relu[0][0]']
#                                 128)
#
#  conv2_block1_1_bn (BatchNormal  (None, None, None,   512        ['conv2_block1_1_conv[0][0]']
#  ization)                       128)
#
#  conv2_block1_1_relu (Activatio  (None, None, None,   0          ['conv2_block1_1_bn[0][0]']
#  n)                             128)
#
#  conv2_block1_2_conv (Conv2D)   (None, None, None,   36864       ['conv2_block1_1_relu[0][0]']
#                                 32)
#
#  conv2_block1_concat (Concatena  (None, None, None,   0          ['pool1[0][0]',
#  te)                            96)                               'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, None, None,   384        ['conv2_block1_concat[0][0]']
#  ization)                       96)
#
#  conv2_block2_0_relu (Activatio  (None, None, None,   0          ['conv2_block2_0_bn[0][0]']
#  n)                             96)
#
#  conv2_block2_1_conv (Conv2D)   (None, None, None,   12288       ['conv2_block2_0_relu[0][0]']
#                                 128)
#
#  conv2_block2_1_bn (BatchNormal  (None, None, None,   512        ['conv2_block2_1_conv[0][0]']
#  ization)                       128)
#
#  conv2_block2_1_relu (Activatio  (None, None, None,   0          ['conv2_block2_1_bn[0][0]']
#  n)                             128)
#
#  conv2_block2_2_conv (Conv2D)   (None, None, None,   36864       ['conv2_block2_1_relu[0][0]']
#                                 32)
#
#  conv2_block2_concat (Concatena  (None, None, None,   0          ['conv2_block1_concat[0][0]',
#  te)                            128)                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, None, None,   512        ['conv2_block2_concat[0][0]']
#  ization)                       128)
#
#  conv2_block3_0_relu (Activatio  (None, None, None,   0          ['conv2_block3_0_bn[0][0]']
#  n)                             128)
#
#  conv2_block3_1_conv (Conv2D)   (None, None, None,   16384       ['conv2_block3_0_relu[0][0]']
#                                 128)
#
#  conv2_block3_1_bn (BatchNormal  (None, None, None,   512        ['conv2_block3_1_conv[0][0]']
#  ization)                       128)
#
#  conv2_block3_1_relu (Activatio  (None, None, None,   0          ['conv2_block3_1_bn[0][0]']
#  n)                             128)
#
#  conv2_block3_2_conv (Conv2D)   (None, None, None,   36864       ['conv2_block3_1_relu[0][0]']
#                                 32)
#
#  conv2_block3_concat (Concatena  (None, None, None,   0          ['conv2_block2_concat[0][0]',
#  te)                            160)                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, None, None,   640        ['conv2_block3_concat[0][0]']
#  ization)                       160)
#
#  conv2_block4_0_relu (Activatio  (None, None, None,   0          ['conv2_block4_0_bn[0][0]']
#  n)                             160)
#
#  conv2_block4_1_conv (Conv2D)   (None, None, None,   20480       ['conv2_block4_0_relu[0][0]']
#                                 128)
#
#  conv2_block4_1_bn (BatchNormal  (None, None, None,   512        ['conv2_block4_1_conv[0][0]']
#  ization)                       128)
#
#  conv2_block4_1_relu (Activatio  (None, None, None,   0          ['conv2_block4_1_bn[0][0]']
#  n)                             128)
#
#  conv2_block4_2_conv (Conv2D)   (None, None, None,   36864       ['conv2_block4_1_relu[0][0]']
#                                 32)
#
#  conv2_block4_concat (Concatena  (None, None, None,   0          ['conv2_block3_concat[0][0]',
#  te)                            192)                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, None, None,   768        ['conv2_block4_concat[0][0]']
#  ization)                       192)
#
#  conv2_block5_0_relu (Activatio  (None, None, None,   0          ['conv2_block5_0_bn[0][0]']
#  n)                             192)
#
#  conv2_block5_1_conv (Conv2D)   (None, None, None,   24576       ['conv2_block5_0_relu[0][0]']
#                                 128)
#
#  conv2_block5_1_bn (BatchNormal  (None, None, None,   512        ['conv2_block5_1_conv[0][0]']
#  ization)                       128)
#
#  conv2_block5_1_relu (Activatio  (None, None, None,   0          ['conv2_block5_1_bn[0][0]']
#  n)                             128)
#
#  conv2_block5_2_conv (Conv2D)   (None, None, None,   36864       ['conv2_block5_1_relu[0][0]']
#                                 32)
#
#  conv2_block5_concat (Concatena  (None, None, None,   0          ['conv2_block4_concat[0][0]',
#  te)                            224)                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, None, None,   896        ['conv2_block5_concat[0][0]']
#  ization)                       224)
#
#  conv2_block6_0_relu (Activatio  (None, None, None,   0          ['conv2_block6_0_bn[0][0]']
#  n)                             224)
#
#  conv2_block6_1_conv (Conv2D)   (None, None, None,   28672       ['conv2_block6_0_relu[0][0]']
#                                 128)
#
#  conv2_block6_1_bn (BatchNormal  (None, None, None,   512        ['conv2_block6_1_conv[0][0]']
#  ization)                       128)
#
#  conv2_block6_1_relu (Activatio  (None, None, None,   0          ['conv2_block6_1_bn[0][0]']
#  n)                             128)
#
#  conv2_block6_2_conv (Conv2D)   (None, None, None,   36864       ['conv2_block6_1_relu[0][0]']
#                                 32)
#
#  conv2_block6_concat (Concatena  (None, None, None,   0          ['conv2_block5_concat[0][0]',
#  te)                            256)                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, None, None,   1024        ['conv2_block6_concat[0][0]']
#                                 256)
#
#  pool2_relu (Activation)        (None, None, None,   0           ['pool2_bn[0][0]']
#                                 256)
#
#  pool2_conv (Conv2D)            (None, None, None,   32768       ['pool2_relu[0][0]']
#                                 128)
#
#  pool2_pool (AveragePooling2D)  (None, None, None,   0           ['pool2_conv[0][0]']
#                                 128)
#
#  conv3_block1_0_bn (BatchNormal  (None, None, None,   512        ['pool2_pool[0][0]']
#  ization)                       128)
#
#  conv3_block1_0_relu (Activatio  (None, None, None,   0          ['conv3_block1_0_bn[0][0]']
#  n)                             128)
#
#  conv3_block1_1_conv (Conv2D)   (None, None, None,   16384       ['conv3_block1_0_relu[0][0]']
#                                 128)
#
#  conv3_block1_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block1_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block1_1_relu (Activatio  (None, None, None,   0          ['conv3_block1_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block1_2_conv (Conv2D)   (None, None, None,   36864       ['conv3_block1_1_relu[0][0]']
#                                 32)
#
#  conv3_block1_concat (Concatena  (None, None, None,   0          ['pool2_pool[0][0]',
#  te)                            160)                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, None, None,   640        ['conv3_block1_concat[0][0]']
#  ization)                       160)
#
#  conv3_block2_0_relu (Activatio  (None, None, None,   0          ['conv3_block2_0_bn[0][0]']
#  n)                             160)
#
#  conv3_block2_1_conv (Conv2D)   (None, None, None,   20480       ['conv3_block2_0_relu[0][0]']
#                                 128)
#
#  conv3_block2_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block2_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block2_1_relu (Activatio  (None, None, None,   0          ['conv3_block2_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block2_2_conv (Conv2D)   (None, None, None,   36864       ['conv3_block2_1_relu[0][0]']
#                                 32)
#
#  conv3_block2_concat (Concatena  (None, None, None,   0          ['conv3_block1_concat[0][0]',
#  te)                            192)                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, None, None,   768        ['conv3_block2_concat[0][0]']
#  ization)                       192)
#
#  conv3_block3_0_relu (Activatio  (None, None, None,   0          ['conv3_block3_0_bn[0][0]']
#  n)                             192)
#
#  conv3_block3_1_conv (Conv2D)   (None, None, None,   24576       ['conv3_block3_0_relu[0][0]']
#                                 128)
#
#  conv3_block3_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block3_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block3_1_relu (Activatio  (None, None, None,   0          ['conv3_block3_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block3_2_conv (Conv2D)   (None, None, None,   36864       ['conv3_block3_1_relu[0][0]']
#                                 32)
#
#  conv3_block3_concat (Concatena  (None, None, None,   0          ['conv3_block2_concat[0][0]',
#  te)                            224)                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, None, None,   896        ['conv3_block3_concat[0][0]']
#  ization)                       224)
#
#  conv3_block4_0_relu (Activatio  (None, None, None,   0          ['conv3_block4_0_bn[0][0]']
#  n)                             224)
#
#  conv3_block4_1_conv (Conv2D)   (None, None, None,   28672       ['conv3_block4_0_relu[0][0]']
#                                 128)
#
#  conv3_block4_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block4_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block4_1_relu (Activatio  (None, None, None,   0          ['conv3_block4_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block4_2_conv (Conv2D)   (None, None, None,   36864       ['conv3_block4_1_relu[0][0]']
#                                 32)
#
#  conv3_block4_concat (Concatena  (None, None, None,   0          ['conv3_block3_concat[0][0]',
#  te)                            256)                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, None, None,   1024       ['conv3_block4_concat[0][0]']
#  ization)                       256)
#
#  conv3_block5_0_relu (Activatio  (None, None, None,   0          ['conv3_block5_0_bn[0][0]']
#  n)                             256)
#
#  conv3_block5_1_conv (Conv2D)   (None, None, None,   32768       ['conv3_block5_0_relu[0][0]']
#                                 128)
#
#  conv3_block5_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block5_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block5_1_relu (Activatio  (None, None, None,   0          ['conv3_block5_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block5_2_conv (Conv2D)   (None, None, None,   36864       ['conv3_block5_1_relu[0][0]']
#                                 32)
#
#  conv3_block5_concat (Concatena  (None, None, None,   0          ['conv3_block4_concat[0][0]',
#  te)                            288)                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, None, None,   1152       ['conv3_block5_concat[0][0]']
#  ization)                       288)
#
#  conv3_block6_0_relu (Activatio  (None, None, None,   0          ['conv3_block6_0_bn[0][0]']
#  n)                             288)
#
#  conv3_block6_1_conv (Conv2D)   (None, None, None,   36864       ['conv3_block6_0_relu[0][0]']
#                                 128)
#
#  conv3_block6_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block6_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block6_1_relu (Activatio  (None, None, None,   0          ['conv3_block6_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block6_2_conv (Conv2D)   (None, None, None,   36864       ['conv3_block6_1_relu[0][0]']
#                                 32)
#
#  conv3_block6_concat (Concatena  (None, None, None,   0          ['conv3_block5_concat[0][0]',
#  te)                            320)                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, None, None,   1280       ['conv3_block6_concat[0][0]']
#  ization)                       320)
#
#  conv3_block7_0_relu (Activatio  (None, None, None,   0          ['conv3_block7_0_bn[0][0]']
#  n)                             320)
#
#  conv3_block7_1_conv (Conv2D)   (None, None, None,   40960       ['conv3_block7_0_relu[0][0]']
#                                 128)
#
#  conv3_block7_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block7_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block7_1_relu (Activatio  (None, None, None,   0          ['conv3_block7_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block7_2_conv (Conv2D)   (None, None, None,   36864       ['conv3_block7_1_relu[0][0]']
#                                 32)
#
#  conv3_block7_concat (Concatena  (None, None, None,   0          ['conv3_block6_concat[0][0]',
#  te)                            352)                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, None, None,   1408       ['conv3_block7_concat[0][0]']
#  ization)                       352)
#
#  conv3_block8_0_relu (Activatio  (None, None, None,   0          ['conv3_block8_0_bn[0][0]']
#  n)                             352)
#
#  conv3_block8_1_conv (Conv2D)   (None, None, None,   45056       ['conv3_block8_0_relu[0][0]']
#                                 128)
#
#  conv3_block8_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block8_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block8_1_relu (Activatio  (None, None, None,   0          ['conv3_block8_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block8_2_conv (Conv2D)   (None, None, None,   36864       ['conv3_block8_1_relu[0][0]']
#                                 32)
#
#  conv3_block8_concat (Concatena  (None, None, None,   0          ['conv3_block7_concat[0][0]',
#  te)                            384)                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, None, None,   1536       ['conv3_block8_concat[0][0]']
#  ization)                       384)
#
#  conv3_block9_0_relu (Activatio  (None, None, None,   0          ['conv3_block9_0_bn[0][0]']
#  n)                             384)
#
#  conv3_block9_1_conv (Conv2D)   (None, None, None,   49152       ['conv3_block9_0_relu[0][0]']
#                                 128)
#
#  conv3_block9_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block9_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block9_1_relu (Activatio  (None, None, None,   0          ['conv3_block9_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block9_2_conv (Conv2D)   (None, None, None,   36864       ['conv3_block9_1_relu[0][0]']
#                                 32)
#
#  conv3_block9_concat (Concatena  (None, None, None,   0          ['conv3_block8_concat[0][0]',
#  te)                            416)                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, None, None,   1664       ['conv3_block9_concat[0][0]']
#  lization)                      416)
#
#  conv3_block10_0_relu (Activati  (None, None, None,   0          ['conv3_block10_0_bn[0][0]']
#  on)                            416)
#
#  conv3_block10_1_conv (Conv2D)  (None, None, None,   53248       ['conv3_block10_0_relu[0][0]']
#                                 128)
#
#  conv3_block10_1_bn (BatchNorma  (None, None, None,   512        ['conv3_block10_1_conv[0][0]']
#  lization)                      128)
#
#  conv3_block10_1_relu (Activati  (None, None, None,   0          ['conv3_block10_1_bn[0][0]']
#  on)                            128)
#
#  conv3_block10_2_conv (Conv2D)  (None, None, None,   36864       ['conv3_block10_1_relu[0][0]']
#                                 32)
#
#  conv3_block10_concat (Concaten  (None, None, None,   0          ['conv3_block9_concat[0][0]',
#  ate)                           448)                              'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, None, None,   1792       ['conv3_block10_concat[0][0]']
#  lization)                      448)
#
#  conv3_block11_0_relu (Activati  (None, None, None,   0          ['conv3_block11_0_bn[0][0]']
#  on)                            448)
#
#  conv3_block11_1_conv (Conv2D)  (None, None, None,   57344       ['conv3_block11_0_relu[0][0]']
#                                 128)
#
#  conv3_block11_1_bn (BatchNorma  (None, None, None,   512        ['conv3_block11_1_conv[0][0]']
#  lization)                      128)
#
#  conv3_block11_1_relu (Activati  (None, None, None,   0          ['conv3_block11_1_bn[0][0]']
#  on)                            128)
#
#  conv3_block11_2_conv (Conv2D)  (None, None, None,   36864       ['conv3_block11_1_relu[0][0]']
#                                 32)
#
#  conv3_block11_concat (Concaten  (None, None, None,   0          ['conv3_block10_concat[0][0]',
#  ate)                           480)                              'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, None, None,   1920       ['conv3_block11_concat[0][0]']
#  lization)                      480)
#
#  conv3_block12_0_relu (Activati  (None, None, None,   0          ['conv3_block12_0_bn[0][0]']
#  on)                            480)
#
#  conv3_block12_1_conv (Conv2D)  (None, None, None,   61440       ['conv3_block12_0_relu[0][0]']
#                                 128)
#
#  conv3_block12_1_bn (BatchNorma  (None, None, None,   512        ['conv3_block12_1_conv[0][0]']
#  lization)                      128)
#
#  conv3_block12_1_relu (Activati  (None, None, None,   0          ['conv3_block12_1_bn[0][0]']
#  on)                            128)
#
#  conv3_block12_2_conv (Conv2D)  (None, None, None,   36864       ['conv3_block12_1_relu[0][0]']
#                                 32)
#
#  conv3_block12_concat (Concaten  (None, None, None,   0          ['conv3_block11_concat[0][0]',
#  ate)                           512)                              'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, None, None,   2048        ['conv3_block12_concat[0][0]']
#                                 512)
#
#  pool3_relu (Activation)        (None, None, None,   0           ['pool3_bn[0][0]']
#                                 512)
#
#  pool3_conv (Conv2D)            (None, None, None,   131072      ['pool3_relu[0][0]']
#                                 256)
#
#  pool3_pool (AveragePooling2D)  (None, None, None,   0           ['pool3_conv[0][0]']
#                                 256)
#
#  conv4_block1_0_bn (BatchNormal  (None, None, None,   1024       ['pool3_pool[0][0]']
#  ization)                       256)
#
#  conv4_block1_0_relu (Activatio  (None, None, None,   0          ['conv4_block1_0_bn[0][0]']
#  n)                             256)
#
#  conv4_block1_1_conv (Conv2D)   (None, None, None,   32768       ['conv4_block1_0_relu[0][0]']
#                                 128)
#
#  conv4_block1_1_bn (BatchNormal  (None, None, None,   512        ['conv4_block1_1_conv[0][0]']
#  ization)                       128)
#
#  conv4_block1_1_relu (Activatio  (None, None, None,   0          ['conv4_block1_1_bn[0][0]']
#  n)                             128)
#
#  conv4_block1_2_conv (Conv2D)   (None, None, None,   36864       ['conv4_block1_1_relu[0][0]']
#                                 32)
#
#  conv4_block1_concat (Concatena  (None, None, None,   0          ['pool3_pool[0][0]',
#  te)                            288)                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, None, None,   1152       ['conv4_block1_concat[0][0]']
#  ization)                       288)
#
#  conv4_block2_0_relu (Activatio  (None, None, None,   0          ['conv4_block2_0_bn[0][0]']
#  n)                             288)
#
#  conv4_block2_1_conv (Conv2D)   (None, None, None,   36864       ['conv4_block2_0_relu[0][0]']
#                                 128)
#
#  conv4_block2_1_bn (BatchNormal  (None, None, None,   512        ['conv4_block2_1_conv[0][0]']
#  ization)                       128)
#
#  conv4_block2_1_relu (Activatio  (None, None, None,   0          ['conv4_block2_1_bn[0][0]']
#  n)                             128)
#
#  conv4_block2_2_conv (Conv2D)   (None, None, None,   36864       ['conv4_block2_1_relu[0][0]']
#                                 32)
#
#  conv4_block2_concat (Concatena  (None, None, None,   0          ['conv4_block1_concat[0][0]',
#  te)                            320)                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, None, None,   1280       ['conv4_block2_concat[0][0]']
#  ization)                       320)
#
#  conv4_block3_0_relu (Activatio  (None, None, None,   0          ['conv4_block3_0_bn[0][0]']
#  n)                             320)
#
#  conv4_block3_1_conv (Conv2D)   (None, None, None,   40960       ['conv4_block3_0_relu[0][0]']
#                                 128)
#
#  conv4_block3_1_bn (BatchNormal  (None, None, None,   512        ['conv4_block3_1_conv[0][0]']
#  ization)                       128)
#
#  conv4_block3_1_relu (Activatio  (None, None, None,   0          ['conv4_block3_1_bn[0][0]']
#  n)                             128)
# ...
#  lization)                      128)
#
#  conv5_block17_1_relu (Activati  (None, None, None,   0          ['conv5_block17_1_bn[0][0]']
#  on)                            128)
#
#  conv5_block17_2_conv (Conv2D)  (None, None, None,   36864       ['conv5_block17_1_relu[0][0]']
#                                 32)
#
#  conv5_block17_concat (Concaten  (None, None, None,   0          ['conv5_block16_concat[0][0]',
#  ate)                           1440)                             'conv5_block17_2_conv[0][0]']
#
#  conv5_block18_0_bn (BatchNorma  (None, None, None,   5760       ['conv5_block17_concat[0][0]']
#  lization)                      1440)
#
#  conv5_block18_0_relu (Activati  (None, None, None,   0          ['conv5_block18_0_bn[0][0]']
#  on)                            1440)
#
#  conv5_block18_1_conv (Conv2D)  (None, None, None,   184320      ['conv5_block18_0_relu[0][0]']
#                                 128)
#
#  conv5_block18_1_bn (BatchNorma  (None, None, None,   512        ['conv5_block18_1_conv[0][0]']
#  lization)                      128)
#
#  conv5_block18_1_relu (Activati  (None, None, None,   0          ['conv5_block18_1_bn[0][0]']
#  on)                            128)
#
#  conv5_block18_2_conv (Conv2D)  (None, None, None,   36864       ['conv5_block18_1_relu[0][0]']
#                                 32)
#
#  conv5_block18_concat (Concaten  (None, None, None,   0          ['conv5_block17_concat[0][0]',
#  ate)                           1472)                             'conv5_block18_2_conv[0][0]']
#
#  conv5_block19_0_bn (BatchNorma  (None, None, None,   5888       ['conv5_block18_concat[0][0]']
#  lization)                      1472)
#
#  conv5_block19_0_relu (Activati  (None, None, None,   0          ['conv5_block19_0_bn[0][0]']
#  on)                            1472)
#
#  conv5_block19_1_conv (Conv2D)  (None, None, None,   188416      ['conv5_block19_0_relu[0][0]']
#                                 128)
#
#  conv5_block19_1_bn (BatchNorma  (None, None, None,   512        ['conv5_block19_1_conv[0][0]']
#  lization)                      128)
#
#  conv5_block19_1_relu (Activati  (None, None, None,   0          ['conv5_block19_1_bn[0][0]']
#  on)                            128)
#
#  conv5_block19_2_conv (Conv2D)  (None, None, None,   36864       ['conv5_block19_1_relu[0][0]']
#                                 32)
#
#  conv5_block19_concat (Concaten  (None, None, None,   0          ['conv5_block18_concat[0][0]',
#  ate)                           1504)                             'conv5_block19_2_conv[0][0]']
#
#  conv5_block20_0_bn (BatchNorma  (None, None, None,   6016       ['conv5_block19_concat[0][0]']
#  lization)                      1504)
#
#  conv5_block20_0_relu (Activati  (None, None, None,   0          ['conv5_block20_0_bn[0][0]']
#  on)                            1504)
#
#  conv5_block20_1_conv (Conv2D)  (None, None, None,   192512      ['conv5_block20_0_relu[0][0]']
#                                 128)
#
#  conv5_block20_1_bn (BatchNorma  (None, None, None,   512        ['conv5_block20_1_conv[0][0]']
#  lization)                      128)
#
#  conv5_block20_1_relu (Activati  (None, None, None,   0          ['conv5_block20_1_bn[0][0]']
#  on)                            128)
#
#  conv5_block20_2_conv (Conv2D)  (None, None, None,   36864       ['conv5_block20_1_relu[0][0]']
#                                 32)
#
#  conv5_block20_concat (Concaten  (None, None, None,   0          ['conv5_block19_concat[0][0]',
#  ate)                           1536)                             'conv5_block20_2_conv[0][0]']
#
#  conv5_block21_0_bn (BatchNorma  (None, None, None,   6144       ['conv5_block20_concat[0][0]']
#  lization)                      1536)
#
#  conv5_block21_0_relu (Activati  (None, None, None,   0          ['conv5_block21_0_bn[0][0]']
#  on)                            1536)
#
#  conv5_block21_1_conv (Conv2D)  (None, None, None,   196608      ['conv5_block21_0_relu[0][0]']
#                                 128)
#
#  conv5_block21_1_bn (BatchNorma  (None, None, None,   512        ['conv5_block21_1_conv[0][0]']
#  lization)                      128)
#
#  conv5_block21_1_relu (Activati  (None, None, None,   0          ['conv5_block21_1_bn[0][0]']
#  on)                            128)
#
#  conv5_block21_2_conv (Conv2D)  (None, None, None,   36864       ['conv5_block21_1_relu[0][0]']
#                                 32)
#
#  conv5_block21_concat (Concaten  (None, None, None,   0          ['conv5_block20_concat[0][0]',
#  ate)                           1568)                             'conv5_block21_2_conv[0][0]']
#
#  conv5_block22_0_bn (BatchNorma  (None, None, None,   6272       ['conv5_block21_concat[0][0]']
#  lization)                      1568)
#
#  conv5_block22_0_relu (Activati  (None, None, None,   0          ['conv5_block22_0_bn[0][0]']
#  on)                            1568)
#
#  conv5_block22_1_conv (Conv2D)  (None, None, None,   200704      ['conv5_block22_0_relu[0][0]']
#                                 128)
#
#  conv5_block22_1_bn (BatchNorma  (None, None, None,   512        ['conv5_block22_1_conv[0][0]']
#  lization)                      128)
#
#  conv5_block22_1_relu (Activati  (None, None, None,   0          ['conv5_block22_1_bn[0][0]']
#  on)                            128)
#
#  conv5_block22_2_conv (Conv2D)  (None, None, None,   36864       ['conv5_block22_1_relu[0][0]']
#                                 32)
#
#  conv5_block22_concat (Concaten  (None, None, None,   0          ['conv5_block21_concat[0][0]',
#  ate)                           1600)                             'conv5_block22_2_conv[0][0]']
#
#  conv5_block23_0_bn (BatchNorma  (None, None, None,   6400       ['conv5_block22_concat[0][0]']
#  lization)                      1600)
#
#  conv5_block23_0_relu (Activati  (None, None, None,   0          ['conv5_block23_0_bn[0][0]']
#  on)                            1600)
#
#  conv5_block23_1_conv (Conv2D)  (None, None, None,   204800      ['conv5_block23_0_relu[0][0]']
#                                 128)
#
#  conv5_block23_1_bn (BatchNorma  (None, None, None,   512        ['conv5_block23_1_conv[0][0]']
#  lization)                      128)
#
#  conv5_block23_1_relu (Activati  (None, None, None,   0          ['conv5_block23_1_bn[0][0]']
#  on)                            128)
#
#  conv5_block23_2_conv (Conv2D)  (None, None, None,   36864       ['conv5_block23_1_relu[0][0]']
#                                 32)
#
#  conv5_block23_concat (Concaten  (None, None, None,   0          ['conv5_block22_concat[0][0]',
#  ate)                           1632)                             'conv5_block23_2_conv[0][0]']
#
#  conv5_block24_0_bn (BatchNorma  (None, None, None,   6528       ['conv5_block23_concat[0][0]']
#  lization)                      1632)
#
#  conv5_block24_0_relu (Activati  (None, None, None,   0          ['conv5_block24_0_bn[0][0]']
#  on)                            1632)
#
#  conv5_block24_1_conv (Conv2D)  (None, None, None,   208896      ['conv5_block24_0_relu[0][0]']
#                                 128)
#
#  conv5_block24_1_bn (BatchNorma  (None, None, None,   512        ['conv5_block24_1_conv[0][0]']
#  lization)                      128)
#
#  conv5_block24_1_relu (Activati  (None, None, None,   0          ['conv5_block24_1_bn[0][0]']
#  on)                            128)
#
#  conv5_block24_2_conv (Conv2D)  (None, None, None,   36864       ['conv5_block24_1_relu[0][0]']
#                                 32)
#
#  conv5_block24_concat (Concaten  (None, None, None,   0          ['conv5_block23_concat[0][0]',
#  ate)                           1664)                             'conv5_block24_2_conv[0][0]']
#
# ==================================================================================================
# Total params: 16,139,840
# Trainable params: 15,945,088
# Non-trainable params: 194,752
# __________________________________________________________________________________________________

# %%
#bottleneck_model = InceptionV3(include_top=False)
#Inception.summary()

# %%
#bottleneck_model    = VGG16(include_top=False)
#bottleneck_model.summary()
'''
bottleneck_model   = DenseNet201(include_top=False)
bottleneck_model.summary()
'''

# %%
test = final_output_84_84[0]
test = test.reshape(1, img_size[0], img_size[1],3)
test_shape = bottleneck_model.predict(test).shape
print(test_shape)
shape = (final_output_84_84.shape[0],test_shape[1],test_shape[2],test_shape[3])
print(shape)
print(shape[1:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b3e207a6d31b> in <module>
#       1 test = final_output_84_84[0]
# ----> 2 test = test.reshape(1, img_size[0], img_size[1],3)
#       3 test_shape = bottleneck_model.predict(test).shape
#       4 print(test_shape)
#       5 shape = (final_output_84_84.shape[0],test_shape[1],test_shape[2],test_shape[3])
#
# ValueError: cannot reshape array of size 90000 into shape (1,70,70,3)

# %%
bottelneck_features = []
for i in final_output_84_84:
    
    i = i.reshape(1, img_size[0], img_size[1],3)
    bottelneck_features.append(bottleneck_model.predict(i))
    print(len(bottelneck_features))
    
    #if len(bottelneck_features)==20000:
        #break
    
bottelneck_features=np.array(bottelneck_features)
print(bottelneck_features.shape)

# %%
#print(np.amax(ubiris_features)  )
bottelneck_features =  bottelneck_features.reshape(shape) #4, 6, 512
print(bottelneck_features.shape)

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm

(X_train, X_test, y_train, y_test) = train_test_split(final_output_84_84, lables,test_size=0.05, random_state=1250)

# %%
from sklearn.metrics import accuracy_score

# %%
from keras.layers import Dense, Flatten,Dropout
from keras.models import Sequential
from keras import optimizers


model = Sequential()
model.add(Flatten(input_shape=(final_output_84_84.shape[1:])))#4, 6, 512
#model.add(Dense(500, activation='relu'))
#model.add(Dropout(0.8))
model.add(Dense(1000, activation='softmax'))
sgd = optimizers.SGD(lr=0.1)
#adam = optimizers.Adam(learning_rate=0.001)


model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])
model.summary()

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='casia_dense_net_0.2_adam.hdf5', verbose=1, save_best_only=True)
#X_train, X_test, y_train, y_test

history=model.fit(X_train,y_train, batch_size=32, epochs=30, shuffle=True,validation_data=(X_test, y_test), verbose=1 ,callbacks=[checkpointer])

# %%
import matplotlib.pyplot as plt
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import roc_curve
y_pred_keras = keras_model.predict(X_test).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred_keras)

# %%
from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.plot(fpr_rf, tpr_rf, label='RF (area = {:.3f})'.format(auc_rf))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
